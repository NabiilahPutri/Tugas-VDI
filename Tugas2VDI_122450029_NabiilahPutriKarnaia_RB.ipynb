# %% [markdown]
# <a href="https://colab.research.google.com/github/NabiilahPutri/Tugas-VDI/blob/main/Tugas2VDI_122450029_NabiilahPutriKarnaia_RB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **NABIILAH PUTRI KARNAIA**
#
# **122450029**
#
# **Kelas RB**

# %% [markdown]
# # **Good Data Visualization**

# %% [markdown]
# **1. The 50 Most Visited Websites in the World**

# %%
from IPython.display import Image
Image("/content/Data Visualization 1.jpeg")

# %% [markdown]
# **Key Principles:**
#
# 1. **Strive for forms and functions (Mencapai keseimbangan antara bentuk dan fungsi)**
#    Gambar ini berhasil menggabungkan bentuk dan fungsi dengan baik. Informasi disajikan secara visual melalui lingkaran-lingkaran yang mewakili ukuran dari popularitas masing-masing website berdasarkan jumlah pengunjung. Ukuran lingkaran memberikan gambaran langsung tentang perbandingan dominasi antar situs. Dari segi fungsi, desain ini sangat efektif untuk mempermudah pemahaman atas data yang besar dan kompleks, terutama bagi mereka yang visual.
#
# 2. **Justifying the selection of everything we do (Membenarkan setiap pilihan yang diambil)**
#    Setiap elemen yang ada dalam gambar ini terlihat memiliki alasan yang jelas. Penggunaan warna yang berbeda untuk kategori situs membantu membedakan kelompok-kelompok tertentu seperti mesin pencari, media sosial, dan e-commerce. Pilihan lingkaran sebagai representasi ukuran dan ranking juga mendukung tujuan utama dari infografik ini, yaitu memvisualisasikan dominasi dan popularitas secara kuantitatif dengan cepat dan mudah.
#
# 3. **Creating accessibility through intuitive design (Menciptakan aksesibilitas melalui desain intuitif)**
#    Desain ini intuitif dan mudah dipahami. Lingkaran-lingkaran yang lebih besar langsung menarik perhatian pengguna, dan semakin kecil lingkaran, semakin rendah rangking situs tersebut. Ada panduan di pojok kanan atas untuk membantu pembaca memahami cara membaca infografik ini. Ini sangat membantu untuk pengguna yang mungkin baru pertama kali melihat format seperti ini. Selain itu, kategori situs ditampilkan secara terpisah sehingga mudah untuk diidentifikasi.
#
# 4. **Never deceive the receiver (Tidak menipu penerima informasi)**
#    Gambar ini menyajikan data yang akurat dengan cara yang sangat jelas tanpa menyesatkan. Tidak ada elemen visual yang memanipulasi informasi secara berlebihan. Skala yang digunakan realistis dan ukuran lingkaran sebanding dengan jumlah pengunjung situs, jadi penerima informasi dapat memahami konteks sebenarnya dengan mudah.
#
# Source: Visual Capitalist

# %% [markdown]
# **2. Popular programming languages on the CRAN network**

# %%
Image("/content/Data Visualization 2.jpeg")

# %% [markdown]
# **Key Principles:**
#
# 1. **Strive for forms and functions (Mencapai keseimbangan antara bentuk dan fungsi)**
#    Gambar ini menggabungkan bentuk dan fungsi dengan baik. Bentuk visual lingkaran berwarna yang proporsional dengan jumlah LOC menarik secara estetika dan sekaligus berfungsi dengan baik untuk menyampaikan informasi. Desain ini memungkinkan pengguna untuk dengan mudah memahami perbandingan ukuran antar bahasa pemrograman yang digunakan di CRAN, terutama dalam hal jumlah kode yang ditulis.
#
# 2. **Justifying the selection of everything we do (Membenarkan setiap pilihan yang diambil)**
#    Pemilihan lingkaran sebagai representasi proporsional dari jumlah LOC sangat tepat. Ini memberikan gambaran yang jelas tentang skala dan memungkinkan pengguna memahami bahasa mana yang dominan secara visual. Warna yang berbeda-beda untuk setiap bahasa pemrograman membantu memperjelas perbedaan antar lingkaran, sehingga keputusan desain ini sepenuhnya mendukung tujuan utama visualisasi.
#
# 3. **Creating accessibility through intuitive design (Menciptakan aksesibilitas melalui desain intuitif)**
#    Desain ini cukup intuitif. Lingkaran dengan ukuran yang proporsional memudahkan pengguna untuk memahami informasi secara langsung. Namun, meskipun sebagian besar label mudah dibaca, ada beberapa label yang mungkin memerlukan lebih banyak perhatian karena penempatan yang terlalu dekat atau tumpang tindih akibat banyaknya elemen yang ditampilkan. Ini membuat visualisasi sedikit kurang ramah bagi pengguna baru atau mereka yang memerlukan keterbacaan lebih baik.
#
# 4. **Never deceive the receiver (Tidak menipu penerima informasi)**
#    Visualisasi ini tidak menipu atau memberikan informasi yang salah. Ukuran lingkaran yang proporsional dan sesuai dengan jumlah LOC memberikan transparansi kepada pengguna. Tidak ada manipulasi atau distorsi data dalam gambar ini, sehingga penerima informasi dapat mempercayai akurasi data yang disajikan.
#
# Source: Dr Torsten Sprenger /GitHub

# %% [markdown]
# # **Bad Data Visualization**

# %% [markdown]
# **1. Streamgraph of immigration to the US**

# %%
Image("/content/Data Visualization 3.jpeg")

# %% [markdown]
# **Key Principles:**
#
# 1. **Strive for forms and functions (Mencapai keseimbangan antara bentuk dan fungsi)**
#    Desain ini menggunakan bentuk aliran berwarna yang menyerupai "sungai" untuk menunjukkan jumlah imigran dari berbagai negara selama rentang waktu yang panjang. Bentuk visual yang tidak konvensional ini menarik perhatian, tetapi fungsinya bisa diperdebatkan. Meski estetis, bentuknya bisa menyulitkan dalam membandingkan ukuran antara aliran-aliran yang berbeda, terutama ketika garis-garis saling bertumpuk.
#
# 2. **Justifying the selection of everything we do (Membenarkan setiap pilihan yang diambil)**
#    Pemilihan warna yang beragam membantu membedakan asal negara imigran, namun penggunaan aliran dengan lebar yang berubah-ubah terkadang membingungkan. Meski setiap warna mewakili negara berbeda, tanpa skala yang jelas, sulit untuk mengukur secara pasti berapa jumlah imigran dari setiap negara pada waktu tertentu. Warna-warna tersebut terlihat semata-mata untuk tujuan estetika, tetapi tidak selalu meningkatkan keterbacaan informasi.
#
# 3. **Creating accessibility through intuitive design (Menciptakan aksesibilitas melalui desain intuitif)**
#    Desain ini mungkin sulit dipahami oleh pengguna yang tidak terbiasa dengan visualisasi berbasis aliran atau "streamgraph". Kurva dan tumpukan warna bisa membingungkan, terutama ketika mencoba melacak perubahan jumlah imigran dari negara tertentu selama beberapa dekade. Meskipun ada legenda yang menunjukkan asal negara, pembaca harus melakukan usaha ekstra untuk menguraikan informasi, yang bisa membuatnya kurang intuitif dibandingkan metode visualisasi lain, seperti grafik batang atau garis sederhana.
#
# 4. **Never deceive the receiver (Tidak menipu penerima informasi)**
#    Visualisasi ini tidak secara sengaja menipu penerima, tetapi cara data disajikan bisa menyesatkan dalam hal interpretasi. Misalnya, tumpukan garis-garis aliran tidak memiliki pembatas yang jelas untuk setiap negara pada sumbu vertikal, sehingga bisa sulit memastikan berapa jumlah yang tepat dari imigran pada setiap tahun. Meski tidak berniat untuk memanipulasi, penyajian data semacam ini rentan terhadap salah tafsir.
#
# Source: Talia Bronshtein / insightfulinteraction.com

# %% [markdown]
# **2. Faktor-Faktor yang Mendorong Gen-Z Keluar dari Tempat Kerja: Hasil Survei 2022**

# %%
Image("/content/Data Visualization 4.jpeg")

# %% [markdown]
# **Key Principles:**
#
# 1. **Strive for forms and functions (Mencapai keseimbangan antara bentuk dan fungsi)**
#    Penggunaan warna-warna cerah seperti merah, kuning, dan pink mungkin terlalu mencolok dan tidak nyaman dilihat dalam waktu yang lama. Hal ini mengurangi pengalaman visual yang menyenangkan. Desain tampaknya terlalu fokus pada bentuk (estetika) dan mengabaikan fungsi. Warna-warna yang terlalu mirip, seperti merah dan oranye, dapat membuat sulit membedakan antara kategori. Selain itu, bagi pengguna yang kurang familiar dengan diagram batang atau sulit memahami persentase, visualisasi ini mungkin tidak memberikan informasi yang langsung jelas.
#
# 2. **Justifying the selection of everything we do (Membenarkan setiap pilihan yang diambil)**
#    Pemilihan warna yang berlebihan dan tidak kontras dengan latar belakang dapat dikritisi. Misalnya, warna merah pada latar belakang yang agak terang membuat teks atau persentase di bagian atas batang sulit terbaca. Tidak ada alasan kuat yang membenarkan pemilihan warna-warna cerah tersebut selain agar terlihat menarik secara visual. Posisi judul dan sumber data yang terletak di bagian bawah gambar terlalu kecil dan tidak mudah terlihat oleh pembaca.
#
# 3. **Creating accessibility through intuitive design (Menciptakan aksesibilitas melalui desain intuitif)**
#    Meskipun diagram batang adalah bentuk visual yang umum, penggunaan warna yang terlalu banyak dan terlalu mencolok bisa mengganggu aksesibilitas. Beberapa warna yang berdekatan, seperti merah dan oranye, memiliki kontras yang kurang sehingga sulit untuk segera dikenali. Selain itu, elemen desain seperti latar belakang bergradasi tidak memberikan kontribusi terhadap penyampaian informasi dan justru bisa mengalihkan perhatian pembaca dari inti data yang ingin disampaikan.
#
# 4. **Never deceive the receiver (Tidak menipu penerima informasi)**
#    Meskipun visualisasi ini tidak secara langsung menyesatkan, penggunaan desain yang berlebihan dan elemen visual yang tidak relevan menyulitkan pembaca dalam memahami data dengan cepat. Warna yang terlalu cerah mungkin memberikan kesan dramatis, tetapi tidak membuat visualisasi ini efektif dalam menyampaikan informasi secara mudah dan jelas.
#
# Source: Instagram / Arduma.id
