# %% [markdown]
# <a href="https://colab.research.google.com/github/NabiilahPutri/Tugas-VDI/blob/main/Tugas3VDI_122450029_Nabiilah%20Putri%20Karnaia_RB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **NABIILAH PUTRI KARNAIA**
#
# **122450029**
#
# **Kelas RB**

# %% [markdown]
# # **About Dataset**
#
# # **Kesejahteraan Pekerja Indonesia**
#
# **Sumber: https://www.kaggle.com/datasets/rezkyyayang/pekerja-sejahtera**
#
# Dataset kesejahteraan pekerja yang dilihat dari pendapatan/upah dan pengeluaran. Sebagai seseorang yang baru saja memasuki dunia kerja, mungkin kita semua akan mengalami kebingungan dimulai dari di daerah mana kita akan bekerja, berapa upah yang akan didapatkan, serta apakah pendapatan tersebut akan mencukupi untuk kebutuhan sehari-hari. Melalui beberapa data yang bersumber dari Badan Pusat Statistik (BPS), dashboard ini mencoba membantu pekerja dalam memilih tempat bekerja berdasarkan beberapa variabel seperti pendapatan dan pengeluaran. Beberapa hal tersebut menjadikan Dashboard Pekerja Sejahtera ini sangat penting dan relevan sebab kondisi persaingan dunia kerja yang sangat ketat sehingga bagi pekerja tentu dibutuhkan perencanaan yang matang termasuk memikirkan kesejahteraannya berdasarkan pilihan-pilihan yang telah dibuat.
#
# **Terdiri dari beberapa dataset, diantaranya:**
#
# 1. Dataset Rata-Rata Upah Pekerja Per Jam dengan disagregasi Provinsi dan Tahun (2015-2022)
# 2. Dataset Rata-Rata Pengeluaran Per Kapita dengan disagregasi Provinsi, Tahun, Jenis Pengeluaran, dan Daerah Tempat Tinggal.

# %% [markdown]
# # **Membuat Visualisasi dengan Menggunakan Library Python:**

# %%
# Mengimport pustaka yang akan digunakan
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #**1. Dataset Rata-Rata Upah Pekerja Per Jam dengan disagregasi Provinsi dan Tahun (2015-2022)**

# %% [markdown]
# # **Menentukan Tujuan, User, Fungsi, dan Tone:**
#
# **1. Tujuan Visualisasi**
#
# Tujuan dari visualisasi ini adalah untuk memberikan gambaran yang jelas tentang perubahan rata-rata upah pekerja per jam di berbagai provinsi di Indonesia dari tahun 2015 hingga 2022. Dengan menampilkan data ini, visualisasi bertujuan untuk:
# - Menggambarkan tren upah dari tahun ke tahun di setiap provinsi.
# - Menyajikan perbandingan antara provinsi yang berbeda untuk melihat perbedaan upah.
# - Membantu pemangku kepentingan dalam memahami dinamika pasar kerja di Indonesia.
#
# **2. Pengguna**
#
# Pengguna dari visualisasi ini mencakup:
# - Pembuat Kebijakan: Mereka yang bertanggung jawab untuk merumuskan kebijakan ketenagakerjaan dan upah. Data ini dapat membantu mereka dalam pengambilan keputusan terkait peraturan upah minimum.
# - Peneliti dan Akademisi: Mereka yang melakukan penelitian tentang hubungan antara upah, produktivitas, dan kondisi ekonomi. Data ini bisa menjadi bagian penting dari analisis mereka.
# - Perusahaan dan Pengusaha: Pihak yang ingin memahami kondisi pasar tenaga kerja untuk menentukan kebijakan upah dan strategi perekrutan.
# - Masyarakat Umum: Individu yang ingin mengetahui tren upah di daerah mereka dan di seluruh Indonesia.
#
# **3. Fungsi Visualisasi**
#
# Fungsi dari visualisasi ini mencakup:
# - Edukasi: Memberikan wawasan tentang pergerakan upah pekerja dari tahun ke tahun, memungkinkan pengguna untuk memahami kondisi ekonomi dan daya beli masyarakat.
# - Analisis Tren: Membantu dalam menganalisis tren upah di berbagai provinsi, serta perbandingan antar daerah, sehingga dapat diidentifikasi daerah yang mengalami peningkatan atau penurunan upah.
# - Dasar untuk Diskusi: Mendorong diskusi di antara pemangku kepentingan, termasuk pembuat kebijakan dan pemimpin industri, tentang perlunya perubahan dalam kebijakan upah dan ketenagakerjaan.
#
# **4. Tone (Nada)**
#
# Nada dari visualisasi ini adalah:
# - Informatif dan Formal: Nada yang digunakan harus bersifat formal dan berorientasi pada data, mengingat audiens yang beragam, termasuk pembuat kebijakan dan peneliti.
# - Analitis dan Kritis: Memberikan ruang untuk analisis yang mendalam, dengan penekanan pada fakta-fakta yang dapat memengaruhi pengambilan keputusan dan kebijakan upah.

# %%
df=pd.read_csv('/content/upah.csv') # Membuka file csv
df.head() # Menampilkan 5 baris pertama Data Frame
# Out:
#          provinsi  upah.2015  upah.2016  upah.2017  upah.2018  upah.2019  \
# 0            ACEH      11226      13627      14809      13814      15065
# 1  SUMATERA UTARA      10618      11646      13396      13257      14061
# 2  SUMATERA BARAT      11241      13206      14378      14431      15210
# 3            RIAU      13303      15506      15182      15613      16270
# 4           JAMBI      12954      13169      14326      14007      14304
#
#    upah.2020  upah.2021  upah.2022
# 0      18099      17037      16772
# 1      15949      15486      15131
# 2      17571      16630      15887
# 3      18411      19144      18626
# 4      15840      16043      16042

# %%
df.tail() # Menampilkan 5 baris terbawah
# Out:
#         provinsi  upah.2015  upah.2016  upah.2017  upah.2018  upah.2019  \
# 30        MALUKU      14525      16153      16275      14923      17306
# 31  MALUKU UTARA      13607      15226      15760      15864      17425
# 32   PAPUA BARAT      17313      18314      19911      21727      22987
# 33         PAPUA      19290      22961      25657      25987      24984
# 34     INDONESIA      11434      14068      14731      15275      15823
#
#     upah.2020  upah.2021  upah.2022
# 30      26198      21156      17006
# 31      23338      21131      18278
# 32      27904      29600      24128
# 33      32138      30382      24097
# 34      17696      18089      17542

# %%
# Menghapus baris di mana kolom 'provinsi' adalah 'INDONESIA'
df = df[df['provinsi'] != 'INDONESIA']

df.tail()
# Out:
#           provinsi  upah.2015  upah.2016  upah.2017  upah.2018  upah.2019  \
# 29  SULAWESI BARAT      14171      11730      12741      12144      13126
# 30          MALUKU      14525      16153      16275      14923      17306
# 31    MALUKU UTARA      13607      15226      15760      15864      17425
# 32     PAPUA BARAT      17313      18314      19911      21727      22987
# 33           PAPUA      19290      22961      25657      25987      24984
#
#     upah.2020  upah.2021  upah.2022
# 29      18136      18072      14774
# 30      26198      21156      17006
# 31      23338      21131      18278
# 32      27904      29600      24128
# 33      32138      30382      24097

# %%
df.shape # Memeriksa jumlah (baris, kolom)
# Out:
# (34, 9)

# %%
df.describe() # Melihat statistik deskriptif data numerik
# Out:
#           upah.2015     upah.2016     upah.2017     upah.2018     upah.2019  \
# count     34.000000     34.000000     34.000000     34.000000     34.000000
# mean   12972.676471  15115.441176  15697.529412  15911.382353  16653.264706
# std     2683.003910   3723.521412   3617.940560   3890.376550   3700.370361
# min     8525.000000   9940.000000  10569.000000  11359.000000  11828.000000
# 25%    11229.750000  12923.000000  12937.000000  13224.750000  13700.250000
# 50%    12665.500000  14132.000000  15002.000000  15268.000000  16059.500000
# 75%    14206.250000  16424.500000  16703.750000  16926.250000  17923.750000
# max    19290.000000  23444.000000  25657.000000  25987.000000  25236.000000
#
#           upah.2020     upah.2021     upah.2022
# count     34.000000     34.000000     34.000000
# mean   19537.764706  19422.970588  17901.470588
# std     4721.598734   4638.767773   4181.441221
# min    12707.000000  12992.000000  11734.000000
# ...

# %%
df.isnull().sum() # Identifikasi apakah terdapat nilai yang hilang (Missing Value)
# Out:
# provinsi     0
# upah.2015    0
# upah.2016    0
# upah.2017    0
# upah.2018    0
# upah.2019    0
# upah.2020    0
# upah.2021    0
# upah.2022    0
# dtype: int64

# %%
df.dtypes # Menampilkan jenis data tiap kolom
# Out:
# provinsi     object
# upah.2015     int64
# upah.2016     int64
# upah.2017     int64
# upah.2018     int64
# upah.2019     int64
# upah.2020     int64
# upah.2021     int64
# upah.2022     int64
# dtype: object

# %%
# Data statistik deskriptif
data = {
    'tahun': ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
    'min': [8525, 9940, 10569, 11359, 11828, 12707, 12992, 11734],
    '25%': [11233.5, 12978, 13090, 13235.5, 13820.5, 15894.5, 16085, 15509],
    '50%': [12660, 14068, 14822, 15275, 15849, 18136, 18271, 17006],
    '75%': [14194.5, 16334, 16670.5, 16898.5, 17757.5, 22212.5, 21085.5, 18849.5],
    'max': [19290, 23444, 25657, 25987, 25236, 32138, 30662, 32685]
}

# Ubah dictionary menjadi dataframe
df_stats = pd.DataFrame(data)

# Set ukuran plot
plt.figure(figsize=(10, 6))

# Loop melalui setiap tahun dan membuat boxplot
# Gunakan min, 25%, 50%, 75%, dan max untuk membuat boxplot per tahun
box_data = [df_stats[['min', '25%', '50%', '75%', 'max']].iloc[i].values for i in range(len(df_stats))]

# Membuat boxplot berdasarkan data deskriptif
plt.boxplot(box_data, labels=df_stats['tahun'], showmeans=True)

# Menambahkan judul dan label
plt.title('Distribusi Upah 2015-2022', fontsize=16)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Upah (IDR)', fontsize=12)

# Menampilkan plot
plt.grid(True)
plt.show()

# %%
# Set ukuran plot
plt.figure(figsize=(12, 10))

# Membuat plot bar upah tahun 2022 per provinsi
sns.barplot(x='upah.2022', y='provinsi', data=df, hue='provinsi', palette='viridis', legend=False)

# Menambahkan judul dan label
plt.title('Upah Minimum Tahun 2022 di Setiap Provinsi', fontsize=16)
plt.xlabel('Upah 2022 (IDR)', fontsize=12)
plt.ylabel('Provinsi', fontsize=12)

# Menampilkan plot
plt.show()

# %%
# Data statistik deskriptif dalam bentuk dictionary
data = {
    'tahun': ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
    'mean': [12928.71, 15085.51, 15669.91, 15893.20, 16629.54, 19485.14, 19384.86, 17891.20],
    'min': [8525, 9940, 10569, 11359, 11828, 12707, 12992, 11734],
    '25%': [11233.5, 12978, 13090, 13235.5, 13820.5, 15894.5, 16085, 15509],
    '50%': [12660, 14068, 14822, 15275, 15849, 18136, 18271, 17006],
    '75%': [14194.5, 16334, 16670.5, 16898.5, 17757.5, 22212.5, 21085.5, 18849.5],
    'max': [19290, 23444, 25657, 25987, 25236, 32138, 30662, 32685]
}

# Konversi ke DataFrame
df_stats = pd.DataFrame(data)

# Set ukuran plot
plt.figure(figsize=(10, 6))

# Plot garis untuk mean, min, dan max
plt.plot(df_stats['tahun'], df_stats['mean'], marker='o', label='Mean')
plt.plot(df_stats['tahun'], df_stats['min'], marker='o', label='Min')
plt.plot(df_stats['tahun'], df_stats['max'], marker='o', label='Max')

# Menambahkan judul dan label
plt.title('Tren Statistik Upah 2015-2022', fontsize=16)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Upah (IDR)', fontsize=12)

# Menampilkan legenda
plt.legend()

# Menampilkan plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **2. Dataset Rata-Rata Pengeluaran Per Kapita dengan disagregasi Provinsi, Tahun, Jenis Pengeluaran, dan Daerah Tempat Tinggal.**

# %% [markdown]
# # **Menentukan Tujuan, User, Fungsi, dan Tone:**
#
# **1. Tujuan Visualisasi**
#
# Tujuan dari visualisasi ini adalah untuk memberikan wawasan tentang tren pengeluaran perkotaan di Indonesia dari tahun 2015 hingga 2022. Dengan menampilkan statistik deskriptif, visualisasi ini bertujuan untuk:
# - Menggambarkan perubahan dalam pengeluaran dari tahun ke tahun.
# - Menyajikan informasi kunci seperti rata-rata, minimum, dan maksimum untuk membantu pengguna memahami variasi dalam pengeluaran.
# - Meningkatkan kesadaran mengenai pola pengeluaran yang mungkin memerlukan perhatian atau intervensi kebijakan.
#
# **2. Pengguna**
#
# Pengguna dari visualisasi ini mencakup:
# - Pembuat Kebijakan: Mereka yang terlibat dalam merumuskan kebijakan publik dan memerlukan data untuk memahami tren pengeluaran masyarakat serta dampaknya terhadap ekonomi.
# - Peneliti dan Akademisi: Mereka yang melakukan studi tentang pengeluaran rumah tangga dan dampaknya terhadap kualitas hidup. Data ini dapat digunakan sebagai referensi dalam penelitian mereka.
# - Masyarakat Umum: Individu yang ingin mengetahui lebih lanjut tentang pengeluaran di perkotaan dan bagaimana hal ini dapat memengaruhi kehidupan mereka sehari-hari.
#
# **3. Fungsi Visualisasi**
#
# Fungsi dari visualisasi ini mencakup:
# - Edukasi: Memberikan pemahaman tentang bagaimana pengeluaran masyarakat berubah seiring waktu, sehingga pengguna dapat mendapatkan gambaran yang lebih baik mengenai kondisi ekonomi.
# - Analisis Tren: Menyediakan alat untuk analisis tren dalam pengeluaran perkotaan yang dapat membantu dalam perencanaan ke depan dan penentuan prioritas kebijakan.
# - Diskusi: Mendorong diskusi di kalangan pembuat kebijakan dan pemangku kepentingan mengenai tindakan yang perlu diambil berdasarkan data yang diperoleh.
#
# **4. Tone (Nada)**
#
# Nada dari visualisasi ini adalah:
# - Informatif dan Serius: Karena audiens terdiri dari pembuat kebijakan dan peneliti, nada yang digunakan harus formal dan informatif, dengan penekanan pada penyampaian data yang akurat dan objektif.
# - Analitis: Nada yang mendukung analisis yang mendalam, dengan fokus pada fakta dan angka untuk mendukung pernyataan atau rekomendasi yang dihasilkan dari data.

# %%
df=pd.read_csv('/content/peng.csv') # Membuka file csv
df.head() # Menampilkan 5 baris pertama Data Frame
# Out:
#          provinsi  peng.perdesaan.makanan.2007  peng.perdesaan.makanan.2008  \
# 0            ACEH                     195176.0                     218781.0
# 1  SUMATERA UTARA                     171299.0                     198301.0
# 2  SUMATERA BARAT                     192079.0                     212391.0
# 3            RIAU                     217296.0                     237941.0
# 4           JAMBI                     179472.0                     200524.0
#
#    peng.perdesaan.makanan.2009  peng.perdesaan.makanan.2010  \
# 0                     247427.0                     275749.0
# 1                     219171.0                     248859.0
# 2                     238274.0                     280748.0
# 3                     263543.0                     276157.0
# 4                     214071.0                     259432.0
#
#    peng.perdesaan.makanan.2011  peng.perdesaan.makanan.2012  \
# 0                     308000.0                     326182.0
# ...

# %%
df.tail() # Menampilkan 5 baris terbawah
# Out:
#         provinsi  peng.perdesaan.makanan.2007  peng.perdesaan.makanan.2008  \
# 30        MALUKU                     144773.0                     155561.0
# 31  MALUKU UTARA                     177675.0                     191156.0
# 32   PAPUA BARAT                     145641.0                     182991.0
# 33         PAPUA                     174794.0                     185796.0
# 34     INDONESIA                     148613.0                     166583.0
#
#     peng.perdesaan.makanan.2009  peng.perdesaan.makanan.2010  \
# 30                     175256.0                     212195.0
# 31                     211978.0                     251754.0
# 32                     239374.0                     246550.0
# 33                     219375.0                     271703.0
# 34                     186741.0                     219803.0
#
#     peng.perdesaan.makanan.2011  peng.perdesaan.makanan.2012  \
# 30                     253671.0                     270796.0
# ...

# %%
# Menghapus baris di mana kolom 'provinsi' adalah 'INDONESIA'
df = df[df['provinsi'] != 'INDONESIA']

df.tail()
# Out:
#           provinsi  peng.perdesaan.makanan.2007  peng.perdesaan.makanan.2008  \
# 29  SULAWESI BARAT                     140620.0                     155240.0
# 30          MALUKU                     144773.0                     155561.0
# 31    MALUKU UTARA                     177675.0                     191156.0
# 32     PAPUA BARAT                     145641.0                     182991.0
# 33           PAPUA                     174794.0                     185796.0
#
#     peng.perdesaan.makanan.2009  peng.perdesaan.makanan.2010  \
# 29                     175342.0                     210483.0
# 30                     175256.0                     212195.0
# 31                     211978.0                     251754.0
# 32                     239374.0                     246550.0
# 33                     219375.0                     271703.0
#
#     peng.perdesaan.makanan.2011  peng.perdesaan.makanan.2012  \
# 29                     211666.0                     224338.0
# ...

# %%
df.shape # Memeriksa jumlah (baris, kolom)
# Out:
# (34, 133)

# %%
df.describe() # Menampilkan statistik deskriptif data numerik
# Out:
#        peng.perdesaan.makanan.2007  peng.perdesaan.makanan.2008  \
# count                    32.000000                    32.000000
# mean                 161964.156250                181569.937500
# std                   32501.321923                 36678.187536
# min                  112287.000000                127838.000000
# 25%                  137860.500000                154906.750000
# 50%                  159143.500000                181955.500000
# 75%                  181894.500000                202471.000000
# max                  248396.000000                277071.000000
#
#        peng.perdesaan.makanan.2009  peng.perdesaan.makanan.2010  \
# count                    32.000000                    32.000000
# mean                 203253.468750                240835.593750
# std                   42122.954192                 42035.428192
# min                  145969.000000                179358.000000
# 25%                  168997.250000                207438.000000
# ...

# %%
df.dtypes # Menampilkan jenis data tiap kolom
# Out:
# provinsi                               object
# peng.perdesaan.makanan.2007           float64
# peng.perdesaan.makanan.2008           float64
# peng.perdesaan.makanan.2009           float64
# peng.perdesaan.makanan.2010           float64
#                                        ...
# peng.perdesaanperkotaan.total.2018      int64
# peng.perdesaanperkotaan.total.2019      int64
# peng.perdesaanperkotaan.total.2020      int64
# peng.perdesaanperkotaan.total.2021      int64
# peng.perdesaanperkotaan.total.2022      int64
# Length: 133, dtype: object

# %%
# Menentukan kolom yang ingin dianalisis (total pengeluaran pedesaan/perkotaan per tahun dari 2015-2022)
selected_columns = ['peng.perdesaanperkotaan.total.2015','peng.perdesaanperkotaan.total.2016',
                    'peng.perdesaanperkotaan.total.2017','peng.perdesaanperkotaan.total.2018',
                    'peng.perdesaanperkotaan.total.2019','peng.perdesaanperkotaan.total.2020',
                    'peng.perdesaanperkotaan.total.2021','peng.perdesaanperkotaan.total.2022']


# Mengambil deskripsi statistik hanya untuk kolom yang diinginkan
description = df[selected_columns].describe()

# Menampilkan deskripsi
print(description)
# Out:
#        peng.perdesaanperkotaan.total.2015  peng.perdesaanperkotaan.total.2016  \
# count                        3.400000e+01                        3.400000e+01
# mean                         8.837217e+05                        9.677159e+05
# std                          2.330037e+05                        2.418652e+05
# min                          5.338910e+05                        5.766270e+05
# 25%                          7.481048e+05                        8.169562e+05
# 50%                          8.250895e+05                        8.995415e+05
# 75%                          9.931708e+05                        1.065033e+06
# max                          1.773431e+06                        1.876648e+06
#
#        peng.perdesaanperkotaan.total.2017  peng.perdesaanperkotaan.total.2018  \
# count                        3.400000e+01                        3.400000e+01
# mean                         1.063852e+06                        1.142416e+06
# ...

# %%
# Data statistik deskriptif untuk pengeluaran perkotaan dari tahun 2015 hingga 2022
data = {
    'tahun': ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
    'min': [533891, 576627, 681483, 704754, 750693, 794361, 840358, 884102],
    '25%': [748104, 816956, 905348, 969832, 1007470, 1065356, 1112809, 1144450],
    '50%': [825089, 899541, 980066, 1080100, 1088359, 1133382, 1188903, 1234662],
    '75%': [993171, 1065033, 1138869, 1240755, 1326594, 1381371, 1412359, 1447031],
    'max': [1773431, 1876648, 1997446, 2039157, 2156112, 2257991, 2336429, 2525347],
}

# Ubah dictionary menjadi DataFrame
df_stats = pd.DataFrame(data)

# Set ukuran plot
plt.figure(figsize=(12, 6))

# Menyusun data untuk boxplot (setiap tahun akan memiliki satu set data)
box_data = [df_stats.iloc[i][['min', '25%', '50%', '75%', 'max']].values for i in range(len(df_stats))]

# Membuat boxplot berdasarkan data deskriptif
plt.boxplot(box_data, labels=df_stats['tahun'], showmeans=True)

# Menambahkan judul dan label
plt.title('Distribusi Pengeluaran Pedesaan/Perkotaan 2015-2022', fontsize=16)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Pengeluaran Perkotaan (IDR)', fontsize=12)

# Menampilkan plot
plt.grid(True)
plt.show()

# %%
# Set ukuran plot
plt.figure(figsize=(12, 10))

# Membuat plot bar untuk pengeluaran perdesaan tahun 2022 per provinsi
sns.barplot(x='peng.perdesaanperkotaan.total.2022', y='provinsi', data=df, palette='viridis')

# Menambahkan judul dan label
plt.title('Pengeluaran Perdesaan/Perkotaan Tahun 2022 di Setiap Provinsi', fontsize=16)
plt.xlabel('Pengeluaran Perdesaan/Perkotaan 2022 (IDR)', fontsize=12)
plt.ylabel('Provinsi', fontsize=12)

# Menampilkan plot
plt.show()
# Out:
# <ipython-input-152-fcf0058e6ae7>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='peng.perdesaanperkotaan.total.2022', y='provinsi', data=df, palette='viridis')

# %%
# Data statistik deskriptif untuk pengeluaran perkotaan dari tahun 2015 hingga 2022
data = {
    'tahun': ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
    'mean': [883721, 967716, 1063852, 1142416, 1190320, 1252577, 1288076, 1338085],
    'min': [533891, 576627, 681483, 704754, 750693, 794361, 840358, 884102],
    '25%': [748104, 816956, 905348, 969832, 1007470, 1065356, 1112809, 1144450],
    '50%': [825089, 899541, 980066, 1080100, 1088359, 1133382, 1188903, 1234662],
    '75%': [993171, 1065033, 1138869, 1240755, 1326594, 1381371, 1412359, 1447031],
    'max': [1773431, 1876648, 1997446, 2039157, 2156112, 2257991, 2336429, 2525347],
}

# Ubah dictionary menjadi DataFrame
df_stats = pd.DataFrame(data)

# Set ukuran plot
plt.figure(figsize=(10, 6))

# Plot garis untuk mean, min, dan max
plt.plot(df_stats['tahun'], df_stats['mean'], marker='o', label='Mean')
plt.plot(df_stats['tahun'], df_stats['min'], marker='o', label='Min')
plt.plot(df_stats['tahun'], df_stats['max'], marker='o', label='Max')

# Menambahkan judul dan label
plt.title('Statistik Pengeluaran Pedesaan/Perkotaan 2015-2022', fontsize=16)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Pengeluaran Perkotaan (IDR)', fontsize=12)

# Menampilkan legenda
plt.legend()

# Menampilkan plot
plt.grid(True)
plt.tight_layout()
plt.show()
